# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nikhilroxtomar/brain-tumor-segmentation")

print("Path to dataset files:", path)

# %%
import shutil

shutil.copytree(
    "/kaggle/input/brain-tumor-segmentation",
    "/content/dataset"
)

# %%
# !git clone https://github.com/KrystianZielinski1998/U-net.git

# %%
# %cd U-net

# %%
# !pip install torchmetrics

# %%
# !pip install wandb -q

import wandb

wandb.login()

# %%
# !python -m main -d dataset --run_name aug_no_clahe --use_aug
